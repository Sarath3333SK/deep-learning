# %%
# Basic Libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import pydot
import seaborn as sns

#Evaluation library
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Deep Learning libraries
import tensorflow as tf
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv("fashion-mnist_train.csv")
fashion_test=pd.read_csv("fashion-mnist_test.csv")

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
X_train_fashion = fashion_train.drop('label',axis = 1)
y_train_fashion = fashion_train['label']
X_test_fashion = fashion_test.drop('label',axis = 1)
y_test_fashion = fashion_test['label']

# %%
#Reshaping the dataset
x_train_reshape = X_train_fashion.values.reshape(-1,28,28)
x_test_reshape = X_test_fashion.values.reshape(-1,28,28)

#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])
plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)

y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
#Creating base neural network
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(10,activation='softmax'),
])

#Compiling the model
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])

#Fitting the model
history=model.fit(X_train_fashion, y_train_fashion, batch_size=100, epochs=30,validation_data=(X_test_fashion, y_test_fashion))
# Out:
# Epoch 1/30
# 600/600 [==============================] - 10s 7ms/step - loss: 1.1336 - accuracy: 0.6239 - val_loss: 0.5728 - val_accuracy: 0.8006
# Epoch 2/30
# 600/600 [==============================] - 4s 6ms/step - loss: 0.7529 - accuracy: 0.7452 - val_loss: 0.5376 - val_accuracy: 0.8161
# Epoch 3/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.6687 - accuracy: 0.7766 - val_loss: 0.4661 - val_accuracy: 0.8451
# Epoch 4/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.6318 - accuracy: 0.7906 - val_loss: 0.4979 - val_accuracy: 0.8512
# Epoch 5/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.6067 - accuracy: 0.8004 - val_loss: 0.4815 - val_accuracy: 0.8546
# Epoch 6/30
# 600/600 [==============================] - 4s 6ms/step - loss: 0.6012 - accuracy: 0.8000 - val_loss: 0.4850 - val_accuracy: 0.8456
# Epoch 7/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5817 - accuracy: 0.8080 - val_loss: 0.4528 - val_accuracy: 0.8599
# Epoch 8/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5725 - accuracy: 0.8081 - val_loss: 0.4659 - val_accuracy: 0.8594
# Epoch 9/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5641 - accuracy: 0.8143 - val_loss: 0.4338 - val_accuracy: 0.8658
# Epoch 10/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5649 - accuracy: 0.8136 - val_loss: 0.4401 - val_accuracy: 0.8560
# Epoch 11/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5587 - accuracy: 0.8155 - val_loss: 0.4551 - val_accuracy: 0.8609
# Epoch 12/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5507 - accuracy: 0.8185 - val_loss: 0.4275 - val_accuracy: 0.8619
# Epoch 13/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5479 - accuracy: 0.8181 - val_loss: 0.4300 - val_accuracy: 0.8648
# Epoch 14/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5395 - accuracy: 0.8212 - val_loss: 0.4229 - val_accuracy: 0.8660
# Epoch 15/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5395 - accuracy: 0.8220 - val_loss: 0.4333 - val_accuracy: 0.8633
# Epoch 16/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5277 - accuracy: 0.8247 - val_loss: 0.4679 - val_accuracy: 0.8616
# Epoch 17/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5267 - accuracy: 0.8249 - val_loss: 0.4301 - val_accuracy: 0.8580
# Epoch 18/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5332 - accuracy: 0.8244 - val_loss: 0.4519 - val_accuracy: 0.8518
# Epoch 19/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5387 - accuracy: 0.8195 - val_loss: 0.4299 - val_accuracy: 0.8639
# Epoch 20/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5374 - accuracy: 0.8215 - val_loss: 0.4391 - val_accuracy: 0.8698
# Epoch 21/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5243 - accuracy: 0.8269 - val_loss: 0.4122 - val_accuracy: 0.8678
# Epoch 22/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5222 - accuracy: 0.8265 - val_loss: 0.4014 - val_accuracy: 0.8674
# Epoch 23/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5236 - accuracy: 0.8267 - val_loss: 0.4076 - val_accuracy: 0.8710
# Epoch 24/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5224 - accuracy: 0.8268 - val_loss: 0.4106 - val_accuracy: 0.8707
# Epoch 25/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5235 - accuracy: 0.8259 - val_loss: 0.4021 - val_accuracy: 0.8697
# Epoch 26/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5134 - accuracy: 0.8299 - val_loss: 0.4052 - val_accuracy: 0.8635
# Epoch 27/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5078 - accuracy: 0.8314 - val_loss: 0.3943 - val_accuracy: 0.8708
# Epoch 28/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5075 - accuracy: 0.8320 - val_loss: 0.3849 - val_accuracy: 0.8727
# Epoch 29/30
# 600/600 [==============================] - 4s 6ms/step - loss: 0.5059 - accuracy: 0.8307 - val_loss: 0.3866 - val_accuracy: 0.8699
# Epoch 30/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5044 - accuracy: 0.8306 - val_loss: 0.4130 - val_accuracy: 0.8596

# %%
test_loss_fashion, test_acc_fashion = model.evaluate(X_test_fashion, y_test_fashion)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4130 - accuracy: 0.8596

# %%
print('Fashion MNIST Test accuracy:', round(test_acc_fashion,4))
# Out:
# Fashion MNIST Test accuracy: 0.8596

# %%
#Predicting the labels-Fashion
y_predict_fash = model.predict(X_test_fashion)
y_predict_fash=np.argmax(y_predict_fash, axis=1)
y_test_fash_eval=np.argmax(y_test_fashion, axis=1)

# %%
con_mat=confusion_matrix(y_test_fash_eval,y_predict_fash)
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,10))
sns.heatmap(con_mat,annot=True,annot_kws={'size': 15},linewidths=0.5,fmt="d",cmap="gray")
plt.title('True or False predicted Fashion MNIST\n',fontweight='bold',fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_fash_eval,y_predict_fash))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82      1000
#            1       0.99      0.97      0.98      1000
#            2       0.79      0.72      0.75      1000
#            3       0.87      0.90      0.88      1000
#            4       0.67      0.92      0.77      1000
#            5       0.98      0.91      0.94      1000
#            6       0.78      0.49      0.60      1000
#            7       0.94      0.89      0.91      1000
#            8       0.97      0.96      0.97      1000
#            9       0.88      0.98      0.93      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
#tf.expand_dims(X_test_digit[0])
y_predict = model.predict(X_test_fashion.loc[[0],:].values)
y_predict=np.argmax(y_predict, axis=1) # Here we get the index of maximum value in the encoded vector
y_test_digit_eval=np.argmax(y_test_fashion, axis=1)

# %%
#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))

plt.imshow(x_train_reshape[0], cmap='gray')
plt.xlabel("Actual:{},Pred:{}".format(col_names[np.argmax(y_test_fashion[0])],col_names[y_predict[0]]))
plt.show()
